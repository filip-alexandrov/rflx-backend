# %%
import requests

url = "https://twitter-api45.p.rapidapi.com/search.php"

query = f"from:FirstSquawk since:2025-08-13 until:2025-08-14 -filter:replies"
        
querystring = {"query":query,"search_type":"Latest"}

headers = {
	"x-rapidapi-key": "e397443822msh6716d33826f9c34p154f6djsn0e6fb053f0f5",
	"x-rapidapi-host": "twitter-api45.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'status': 'ok', 'timeline': [{'type': 'tweet', 'tweet_id': '1955779914520576339', 'screen_name': 'FirstSquawk', 'bookmarks': 1, 'favorites': 28, 'created_at': 'Wed Aug 13 23:54:02 +0000 2025', 'text': 'Japan’s Nikkei Futures Down 0.67% In Early Trade', 'lang': 'en', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'quotes': 2, 'replies': 6, 'conversation_id': '1955779914520576339', 'retweets': 1, 'views': '11698', 'entities': {'hashtags': [], 'symbols': [], 'timestamps': [], 'urls': [], 'user_mentions': []}, 'user_info': {'screen_name': 'FirstSquawk', 'name': 'First Squawk', 'created_at': 'Sun Jul 26 14:40:19 +0000 2015', 'description': 'Firstsquawk Is a Global Financial (News) Squawk Service Specialising In Financial Markets, Macro, Geopolitics,politics', 'rest_id': '3295423333', 'followers_count': 392265, 'favourites_count': 842, 'avatar': 'https://pbs.twimg.com/profile_images/1039778545738964992/6fl6RNN0_normal.jpg', 'verified': True, 'friends_count': 255, 'location': None}, 'media': []}, {'type': 'tweet', 'tweet_id': '1955779881285116209', 'screen_name': 'FirstSquawk', 'bookmarks': 0, 'favorites': 10, 'created_at': 'Wed Aug 13 23:53:54 +0000 2025', 'text': 'Benchmark 10-Year JGB Futures Down 0.45 Point In Early Trade', 'lang': 'en', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'quotes': 0, 'replies': 6, 'conversation_id': '1955779881285116209', 'retweets': 0, 'views': '9024', 'entities': {'hashtags': [], 'symbols': [], 'timestamps': [], 'urls': [], 'user_mentions': []}, 'user_info': {'screen_name': 'FirstSquawk', 'name': 'First Squawk', 'created_at': 'Sun Jul 26 14:40:19 +0000 2015', 'description': 'Firstsquawk Is a Global Financial (News) Squawk Service Specialising In Financial Markets, Macro, Geopolitics,politics', 'rest_id': '3295423333', 'followers_count': 392265, 'favourites_count': 842, 'avatar': 'https://pbs.twimg.com/profile_images/1039778545738964992/6fl6RNN0_normal.jpg', 'verified': True, 'friends_count': 255, 'location': None}, 'media': []}, {'type': 'tweet', 'tweet_id': '1955779431705813404', 'screen_name': 'FirstSquawk', 'bookmarks': 0, 'favorites': 9, 'created_at': 'Wed Aug 13 23:52:07 +0000 2025', 'text': 'Lenovo – Q1 Results:\n\nOperating Profit: $784.8M\n\nRevenue: $18.83B\n\nGross Margin: 14.7%\n\nNet Income: $505.3M', 'lang': 'en', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'quotes': 0, 'replies': 6, 'conversation_id': '1955779431705813404', 'retweets': 1, 'views': '9221', 'entities': {'hashtags': [], 'symbols': [], 'timestamps': [], 'urls': [], 'user_mentions': []}, 'user_info': {'screen_name': 'FirstSquawk', 'name': 'First Squawk', 'created_at': 'Sun Jul 26 14:40:19 +0000 2015', 'description': 'Firstsquawk Is a Global Financial (News) Squawk Service Specialising In Financial Markets, Macro, Geopolitics,politics', 'rest_id': '3295423333', 'followers_count': 392265, 'favourites_count': 842, 'avatar': 'https://pbs.twimg.com/profile_images/1039778545738964992/6fl6RNN0_normal.jpg', 'verified': True, 'friends_count': 255, 'location': None}, 'media': []}, {'type': 'tweet', 'tweet_id': '1955777381966245963', 'screen_name': 'FirstSquawk', 'bookmarks': 3, 'favorites': 21, 'created_at': 'Wed Aug 13 23:43:59 +0000 2025', 'text': 'Treasury Secretary Scott Bessent has been granted until Dec. 15 to complete divesting his remaining assets, mostly illiquid farmland, after missing an earlier ethics deadline.', 'lang': 'en', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'quotes': 1, 'replies': 3, 'conversation_id': '1955777381966245963', 'retweets': 2, 'views': '11202', 'entities': {'hashtags': [], 'symbols': [], 'timestamps': [], 'urls': [], 'user_mentions': []}, 'user_info': {'screen_name': 'FirstSquawk', 'name': 'First Squawk', 'created_at': 'Sun Jul 26 14:40:19 +0000 2015', 'description': 'Firstsquawk Is a Global Financial (News) Squawk Service Specialising In  ...

# %%
base_url = "https://twitter-api45.p.rapidapi.com/search.php"

headers = {
	"x-rapidapi-key": "e397443822msh6716d33826f9c34p154f6djsn0e6fb053f0f5",
	"x-rapidapi-host": "twitter-api45.p.rapidapi.com"
}
end_date = "2025-08-15"
start_date = "2025-08-14"
account = "FirstSquawk"
query = f"from:{account} since:{start_date} until:{end_date} -filter:replies"
querystring = {"query": query, "search_type":"Latest"}
response = requests.get(base_url, headers=headers, params=querystring)

response.json()
# Out:
# {'status': 'ok',
#  'timeline': [{'type': 'tweet',
#    'tweet_id': '1956143407518171354',
#    'screen_name': 'FirstSquawk',
#    'bookmarks': 2,
#    'favorites': 6,
#    'created_at': 'Thu Aug 14 23:58:26 +0000 2025',
#    'text': 'Gold is heading for a weekly drop as stronger US inflation data cut expectations for a September Fed rate cut, pushing yields and the dollar higher.',
#    'lang': 'en',
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'quotes': 2,
#    'replies': 5,
#    'conversation_id': '1956143407518171354',
#    'retweets': 5,
#    'views': '9209',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'timestamps': [],
#     'urls': [],
#     'user_mentions': []},
#    'user_info': {'screen_name': 'FirstSquawk',
#     'name': 'First Squawk',
#     'created_at': 'Sun Jul 26 14:40:19 +0000 2015',
#     'description': 'Firstsquawk Is a Global Financial (News) Squawk Service Specialising In Financial Markets, Macro, Geopolitics,politics',
#     'rest_id': '3295423333',
#     'followers_count': 392265,
#     'favourites_count': 842,
#     'avatar': 'https://pbs.twimg.com/profile_images/1039778545738964992/6fl6RNN0_normal.jpg',
#     'verified': True,
#     'friends_count': 255,
#     'location': None},
#    'media': []},
#   {'type': 'tweet',
#    'tweet_id': '1956142305615761485',
#    'screen_name': 'FirstSquawk',
#    'bookmarks': 2,
#    'favorites': 8,
#    'created_at': 'Thu Aug 14 23:54:03 +0000 2025',
#    'text': 'Japan Weekly Order Flows (Aug 8):\n\nJapan Buying Foreign Bonds: ¥254.9B (prev -¥526.3B)\n\nJapan Buying Foreign Stocks: -¥225.5B (prev -¥752.1B)\n\nForeign Buying Japan Bonds: ¥733.2B (prev -¥87.5B)\n\nForeign Buying Japan Stocks: ¥489.3B (prev ¥193.0B)',
#    'lang': 'en',
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'quotes': 0,
#    'replies': 4,
#    'conversation_id': '1956142305615761485',
#    'retweets': 2,
#    'views': '9376',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'timestamps': [],
#     'urls': [],
#     'user_mentions': []},
#    'user_info': {'screen_name': 'FirstSquawk',
#     'name': 'First Squawk',
#     'created_at': 'Sun Jul 26 14:40:19 +0000 2015',
#     'description': 'Firstsquawk Is a Global Financial (News) Squawk Service Specialising In Financial Markets, Macro, Geopolitics,politics',
#     'rest_id': '3295423333',
#     'followers_count': 392265,
#     'favourites_count': 842,
#     'avatar': 'https://pbs.twimg.com/profile_images/1039778545738964992/6fl6RNN0_normal.jpg',
#     'verified': True,
#     'friends_count': 255,
#     'location': None},
#    'media': []},
#   {'type': 'tweet',
#    'tweet_id': '1956142002367561857',
#    'screen_name': 'FirstSquawk',
#    'bookmarks': 0,
#    'favorites': 5,
#    'created_at': 'Thu Aug 14 23:52:51 +0000 2025',
#    'text': 'Japan Q2 Prelim GDP Beats Estimates:\n\nGDP SA QoQ: 0.3% (est 0.1%; prev 0.0%)\n\nAnnualised QoQ: 1.0% (est 0.4%; prev -0.2%)\n\nNominal SA QoQ: 1.3% (est 1.4%; prev 0.9%)\n\nGDP Deflator YoY: 3.0% (est 3.2%; prev 3.3%)\n\nPrivate Consumption QoQ: 0.2% (est 0.1%; prev 0.1%)\n\nBusiness Spending QoQ: 1.3% (est 0.7%; prev 1.1%)\n\nInventory Contribution: -0.3% (est -0.2%; prev 0.6%)\n\nNet Exports Contribution: 0.3% (est 0.1%; prev -0.8%)',
#    'lang': 'en',
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'quotes': 0,
#    'replies': 5,
#    'conversation_id': '1956142002367561857',
#    'retweets': 1,
#    'views': '8744',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'user_info': {'screen_name': 'FirstSquawk',
#     'name': 'First Squawk',
#     'created_at': 'Sun Jul 26 14:40:19 +0000 2015',
#     'description': 'Firstsquawk Is a Global Financial (News) Squawk Service Specialising In Financial Markets, Macro, Geopolitics,politics',
#     'rest_id': '3295423333',
#     'followers_count': 392265,
#     'favourites_count': 842,
#     'avatar': 'https://pbs.twimg.com/profile_images/1039778545738964992/6fl6RNN0_normal.jpg',
#     'verified': True,
#     'friends_count': 255,
#     'location': None},
#    'media': []},
#   {'type': 'tweet',
#    'tweet_id': '1956141914572644582',
#    'screen_name': 'FirstSquawk',
#    'bookmarks': 1,
#    'favorites': 2,
#    'created_at': 'Thu Aug 14 23:52:30 +0000 2025',
#    'text': 'Japan Prelim GDP Deflator YoY: 3% (Forecast 3.2%, Prev 3.3%)',
#    'lang': 'en',
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'quotes': 0,
#    'replies': 4,
#    'conversation_id': '1956141914572644582',
#    'retweets': 0,
#    'views': '7700',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'timestamps': [],
#     'urls': [],
#     'user_mentions': []},
#    'user_info': {'screen_name': 'FirstSquawk',
#     'name': 'First Squawk',
#     'created_at': 'Sun Jul 26 14:40:19 +0000 2015',
#     'description': 'Firstsquawk Is a Global Financial (News) Squawk Service Specialising In Financial Markets, Macro, Geopolitics,politics',
#     'rest_id': '3295423333',
#     'followers_count': 392265,
#     'favourites_count': 842,
#     'avatar': 'https://pbs.twimg.com/profile_images/1039778545738964992/6fl6RNN0_normal.jpg',
#     'verified': True,
#     'friends_count': 255,
#     'location': None},
#    'media': []},
#   {'type': 'tweet',
#    'tweet_id': '1956141888026894409',
#    'screen_name': 'FirstSquawk',
#    'bookmarks': 1,
#    'favorites': 1,
#    'created_at': 'Thu Aug 14 23:52:24 +0000 2025',
#    'text': 'Japan GDP QoQ: 0.3% (Forecast 0.1%, Prev 0.0%)',
#    'lang': 'en',
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'quotes': 0,
#    'replies': 3,
#    'conversation_id': '1956141888026894409',
#    'retweets': 0,
#    'views': '7486',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'timestamps': [],
#     'urls': [],
#     'user_mentions': []},
#    'user_info': {'screen_name': 'FirstSquawk',
#     'name': 'First Squawk',
#     'created_at': 'Sun Jul 26 14:40:19 +0000 2015',
#     'description': 'Firstsquawk Is a Global Financial (News) Squawk Service Specialising In Financial Markets, Macro, Geopolitics,politics',
#     'rest_id': '3295423333',
#     'followers_count': 392265,
#     'favourites_count': 842,
#     'avatar': 'https://pbs.twimg.com/profile_images/1039778545738964992/6fl6RNN0_normal.jpg',
#     'verified': True,
#     'friends_count': 255,
#     'location': None},
#    'media': []},
#   {'type': 'tweet',
#    'tweet_id': '1956141863561519439',
#    'screen_name': 'FirstSquawk',
#    'bookmarks': 1,
#    'favorites': 1,
#    'created_at': 'Thu Aug 14 23:52:18 +0000 2025',
#    'text': 'Japan Foreign Bond Investment: ¥254.9B (Prev -¥526.3B)',
#    'lang': 'en',
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'quotes': 0,
#    'replies': 2,
#    'conversation_id': '1956141863561519439',
#    'retweets': 0,
#    'views': '7442',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'timestamps': [],
#     'urls': [],
#     'user_mentions': []},
#    'user_info': {'screen_name': 'FirstSquawk',
#     'name': 'First Squawk',
#     'created_at': 'Sun Jul 26 14:40:19 +0000 2015',
#     'description': 'Firstsquawk Is a Global Financial (News) Squawk Service Specialising In Financial Markets, Macro, Geopolitics,politics',
#     'rest_id': '3295423333',
#     'followers_count': 392265,
#     'favourites_count': 842,
#     'avatar': 'https://pbs.twimg.com/profile_images/1039778545738964992/6fl6RNN0_normal.jpg',
#     'verified': True,
#     'friends_count': 255,
#     'location': None},
#    'media': []},
#   {'type': 'tweet',
#    'tweet_id': '1956141835337789604',
#    'screen_name': 'FirstSquawk',
#    'bookmarks': 2,
#    'favorites': 4,
#    'created_at': 'Thu Aug 14 23:52:11 +0000 2025',
#    'text': 'Japan GDP Annualised QoQ: 1.0% (Forecast 0.4%, Prev -0.2%)',
#    'lang': 'en',
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'quotes': 0,
#    'replies': 4,
#    'conversation_id': '1956141835337789604',
#    'retweets': 1,
#    'views': '7679',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'timestamps': [],
#     'urls': [],
#     'user_mentions': []},
#    'user_info': {'screen_name': 'FirstSquawk',
#     'name': 'First Squawk',
#     'created_at': 'Sun Jul 26 14:40:19 +0000 2015',
#     'description': 'Firstsquawk Is a Global Financial (News) Squawk Service Specialising In Financial Markets, Macro, Geopolitics,politics',
#     'rest_id': '3295423333',
#     'followers_count': 392265,
#     'favourites_count': 842,
#     'avatar': 'https://pbs.twimg.com/profile_images/1039778545738964992/6fl6RNN0_normal.jpg',
#     'verified': True,
#     'friends_count': 255,
#     'location': None},
#    'media': []},
#   {'type': 'tweet',
#    'tweet_id': '1956141144837902581',
#    'screen_name': 'FirstSquawk',
#    'bookmarks': 0,
#    'favorites': 1,
#    'created_at': 'Thu Aug 14 23:49:26 +0000 2025',
#    'text': 'Benchmark 10-Year JGB Futures Down 0.1 Point In Early Trade',
#    'lang': 'en',
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'quotes': 0,
#    'replies': 3,
#    'conversation_id': '1956141144837902581',
#    'retweets': 0,
#    'views': '7187',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'timestamps': [],
#     'urls': [],
#     'user_mentions': []},
#    'user_info': {'screen_name': 'FirstSquawk',
#     'name': 'First Squawk',
#     'created_at': 'Sun Jul 26 14:40:19 +0000 2015',
#     'description': 'Firstsquawk Is a Global Financial (News) Squawk Service Specialising In Financial Markets, Macro, Geopolitics,politics',
#     'rest_id': '3295423333',
#     'followers_count': 392265,
#     'favourites_count': 842,
#     'avatar': 'https://pbs.twimg.com/profile_images/1039778545738964992/6fl6RNN0_normal.jpg',
#     'verified': True,
#     'friends_count': 255,
#     'location': None},
#    'media': []},
#   {'type': 'tweet',
#    'tweet_id': '1956141122788720985',
#    'screen_name': 'FirstSquawk',
#    'bookmarks': 0,
#    'favorites': 1,
#    'created_at': 'Thu Aug 14 23:49:21 +0000 2025',
#    'text': 'Japan’s Nikkei Futures Rise 0.4% In Early Trade',
#    'lang': 'en',
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'quotes': 0,
#    'replies': 2,
#    'conversation_id': '1956141122788720985',
#    'retweets': 0,
#    'views': '7026',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'timestamps': [],
#     'urls': [],
#     'user_mentions': []},
#    'user_info': {'screen_name': 'FirstSquawk',
#     'name': 'First Squawk',
#     'created_at': 'Sun Jul 26 14:40:19 +0000 2015',
#     'description': 'Firstsquawk Is a Global Financial (News) Squawk Service Specialising In Financial Markets, Macro, Geopolitics,politics',
#     'rest_id': '3295423333',
#     'followers_count': 392265,
#     'favourites_count': 842,
#     'avatar': 'https://pbs.twimg.com/profile_images/1039778545738964992/6fl6RNN0_normal.jpg',
#     'verified': True,
#     'friends_count': 255,
#     'location': None},
#    'media': []},
#   {'type': 'tweet',
#    'tweet_id': '1956140803975471338',
#    'screen_name': 'FirstSquawk',
#    'bookmarks': 0,
#    'favorites': 6,
#    'created_at': 'Thu Aug 14 23:48:05 +0000 2025',
#    'text': 'Asian markets faced a muted open after stronger-than-expected US wholesale inflation dampened Wall Street’s rally and pushed bond yields higher, reducing the odds of a September Fed rate cut from near certainty to about 90%.',
#    'lang': 'en',
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'quotes': 1,
#    'replies': 2,
#    'conversation_id': '1956140803975471338',
#    'retweets': 1,
#    'views': '7742',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'timestamps': [],
#     'urls': [],
#     'user_mentions': []},
#    'user_info': {'screen_name': 'FirstSquawk',
#     'name': 'First Squawk',
#     'created_at': 'Sun Jul 26 14:40:19 +0000 2015',
#     'description': 'Firstsquawk Is a Global Financial (News) Squawk Service Specialising In Financial Markets, Macro, Geopolitics,politics',
#     'rest_id': '3295423333',
#     'followers_count': 392265,
#     'favourites_count': 842,
#     'avatar': 'https://pbs.twimg.com/profile_images/1039778545738964992/6fl6RNN0_normal.jpg',
#     'verified': True,
#     'friends_count': 255,
#     'location': None},
#    'media': []},
#   {'type': 'tweet',
#    'tweet_id': '1956139009207587041',
#    'screen_name': 'FirstSquawk',
#    'bookmarks': 1,
#    'favorites': 5,
#    'created_at': 'Thu Aug 14 23:40:57 +0000 2025',
#    'text': 'Oil prices held steady at the week’s close as markets awaited the Trump-Putin meeting, with WTI near $64 and Brent above $66, while supply glut fears and fresh Ukrainian strikes on Russian energy sites kept sentiment cautious.',
#    'lang': 'en',
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'quotes': 0,
#    'replies': 1,
#    'conversation_id': '1956139009207587041',
#    'retweets': 1,
#    'views': '8380',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'timestamps': [],
#     'urls': [],
#     'user_mentions': []},
#    'user_info': {'screen_name': 'FirstSquawk',
#     'name': 'First Squawk',
#     'created_at': 'Sun Jul 26 14:40:19 +0000 2015',
#     'description': 'Firstsquawk Is a Global Financial (News) Squawk Service Specialising In Financial Markets, Macro, Geopolitics,politics',
#     'rest_id': '3295423333',
#     'followers_count': 392265,
#     'favourites_count': 842,
#     'avatar': 'https://pbs.twimg.com/profile_images/1039778545738964992/6fl6RNN0_normal.jpg',
#     'verified': True,
#     'friends_count': 255,
#     'location': None},
#    'media': []},
#   {'type': 'tweet',
#    'tweet_id': '1956138774590840972',
#    'screen_name': 'FirstSquawk',
#    'bookmarks': 3,
#    'favorites': 43,
#    'created_at': 'Thu Aug 14 23:40:01 +0000 2025',
#    'text': 'Trump: Says Alaska Meeting With Putin Has 25% Chance Of Failure – CTX',
#    'lang': 'en',
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'quotes': 4,
#    'replies': 2,
#    'conversation_id': '1956138774590840972',
#    'retweets': 7,
#    'views': '18282',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'timestamps': [],
#     'urls': [],
#     'user_mentions': []},
#    'user_info': {'screen_name': 'FirstSquawk',
#     'name': 'First Squawk',
#     'created_at': 'Sun Jul 26 14:40:19 +0000 2015',
#     'description': 'Firstsquawk Is a Global Financial (News) Squawk Service Specialising In Financial Markets, Macro, Geopolitics,politics',
#     'rest_id': '3295423333',
#     'followers_count': 392265,
#     'favourites_count': 842,
#     'avatar': 'https://pbs.twimg.com/profile_images/1039778545738964992/6fl6RNN0_normal.jpg',
#     'verified': True,
#     'friends_count': 255,
#     'location': None},
#    'media': []},
#   {'type': 'tweet',
#    'tweet_id': '1956131137144721504',
#    'screen_name': 'FirstSquawk',
#    'bookmarks': 0,
#    'favorites': 31,
#    'created_at': 'Thu Aug 14 23:09:40 +0000 2025',
#    'text': 'Bill Ackman’s Pershing Square disclosed a $1.3 billion Amazon stake, totaling over 5.8 million shares, after buying in during a tariff-driven slump earlier this year.',
#    'lang': 'en',
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'quotes': 4,
#    'replies': 7,
#    'conversation_id': '1956131137144721504',
#    'retweets': 7,
#    'views': '47815',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'timestamps': [],
#     'urls': [],
#     'user_mentions': []},
#    'user_info': {'screen_name': 'FirstSquawk',
#     'name': 'First Squawk',
#     'created_at': 'Sun Jul 26 14:40:19 +0000 2015',
#     'description': 'Firstsquawk Is a Global Financial (News) Squawk Service Specialising In Financial Markets, Macro, Geopolitics,politics',
#     'rest_id': '3295423333',
#     'followers_count': 392265,
#     'favourites_count': 842,
#     'avatar': 'https://pbs.twimg.com/profile_images/1039778545738964992/6fl6RNN0_normal.jpg',
#     'verified': True,
#     'friends_count': 255,
#     'location': None},
#    'media': []},
#   {'type': 'tweet',
#    'tweet_id': '1956125435634573397',
#    'screen_name': 'FirstSquawk',
#    'bookmarks': 0,
#    'favorites': 3,
#    'created_at': 'Thu Aug 14 22:47:01 +0000 2025',
#    'text': 'New Zealand Jun Net Migration SA: 1,670 (Prev 1,530; Rev 1,370)',
#    'lang': 'en',
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'quotes': 0,
#    'replies': 2,
#    'conversation_id': '1956125435634573397',
#    'retweets': 0,
#    'views': '9200',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'timestamps': [],
#     'urls': [],
#     'user_mentions': []},
#    'user_info': {'screen_name': 'FirstSquawk',
#     'name': 'First Squawk',
#     'created_at': 'Sun Jul 26 14:40:19 +0000 2015',
#     'description': 'Firstsquawk Is a Global Financial (News) Squawk Service Specialising In Financial Markets, Macro, Geopolitics,politics',
#     'rest_id': '3295423333',
#     'followers_count': 392265,
#     'favourites_count': 842,
#     'avatar': 'https://pbs.twimg.com/profile_images/1039778545738964992/6fl6RNN0_normal.jpg',
#     'verified': True,
#     'friends_count': 255,
#     'location': None},
#    'media': []},
#   {'type': 'tweet',
#    'tweet_id': '1956125337617629353',
#    'screen_name': 'FirstSquawk',
#    'bookmarks': 0,
#    'favorites': 2,
#    'created_at': 'Thu Aug 14 22:46:38 +0000 2025',
#    'text': 'Cloud Startup Vercel Receives Offers Valuing It At $9B – Information',
#    'lang': 'en',
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'quotes': 0,
#    'replies': 3,
#    'conversation_id': '1956125337617629353',
#    'retweets': 1,
#    'views': '9235',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'timestamps': [],
#     'urls': [],
#     'user_mentions': []},
#    'user_info': {'screen_name': 'FirstSquawk',
#     'name': 'First Squawk',
#     'created_at': 'Sun Jul 26 14:40:19 +0000 2015',
#     'description': 'Firstsquawk Is a Global Financial (News) Squawk Service Specialising In Financial Markets, Macro, Geopolitics,politics',
#     'rest_id': '3295423333',
#     'followers_count': 392265,
#     'favourites_count': 842,
#     'avatar': 'https://pbs.twimg.com/profile_images/1039778545738964992/6fl6RNN0_normal.jpg',
#     'verified': True,
#     'friends_count': 255,
#     'location': None},
#    'media': []},
#   {'type': 'tweet',
#    'tweet_id': '1956125192088117443',
#    'screen_name': 'FirstSquawk',
#    'bookmarks': 1,
#    'favorites': 1,
#    'created_at': 'Thu Aug 14 22:46:03 +0000 2025',
#    'text': 'New Zealand Jul Food Prices Rise 0.7% M/M (Prev 1.2%)',
#    'lang': 'en',
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'quotes': 0,
#    'replies': 3,
#    'conversation_id': '1956125192088117443',
#    'retweets': 0,
#    'views': '8788',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'timestamps': [],
#     'urls': [],
#     'user_mentions': []},
#    'user_info': {'screen_name': 'FirstSquawk',
#     'name': 'First Squawk',
#     'created_at': 'Sun Jul 26 14:40:19 +0000 2015',
#     'description': 'Firstsquawk Is a Global Financial (News) Squawk Service Specialising In Financial Markets, Macro, Geopolitics,politics',
#     'rest_id': '3295423333',
#     'followers_count': 392265,
#     'favourites_count': 842,
#     'avatar': 'https://pbs.twimg.com/profile_images/1039778545738964992/6fl6RNN0_normal.jpg',
#     'verified': True,
#     'friends_count': 255,
#     'location': None},
#    'media': []},
#   {'type': 'tweet',
#    'tweet_id': '1956114304580633086',
#    'screen_name': 'FirstSquawk',
#    'bookmarks': 2,
#    'favorites': 4,
#    'created_at': 'Thu Aug 14 22:02:47 +0000 2025',
#    'text': 'Amazon Exploring New Carbon-Free Energy Sources To Complement Renewables And Meet Company Needs',
#    'lang': 'en',
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'quotes': 0,
#    'replies': 1,
#    'conversation_id': '1956114304580633086',
#    'retweets': 1,
#    'views': '10595',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'timestamps': [],
#     'urls': [],
#     'user_mentions': []},
#    'user_info': {'screen_name': 'FirstSquawk',
#     'name': 'First Squawk',
#     'created_at': 'Sun Jul 26 14:40:19 +0000 2015',
#     'description': 'Firstsquawk Is a Global Financial (News) Squawk Service Specialising In Financial Markets, Macro, Geopolitics,politics',
#     'rest_id': '3295423333',
#     'followers_count': 392265,
#     'favourites_count': 842,
#     'avatar': 'https://pbs.twimg.com/profile_images/1039778545738964992/6fl6RNN0_normal.jpg',
#     'verified': True,
#     'friends_count': 255,
#     'location': None},
#    'media': []},
#   {'type': 'tweet',
#    'tweet_id': '1956114222628196862',
#    'screen_name': 'FirstSquawk',
#    'bookmarks': 2,
#    'favorites': 21,
#    'created_at': 'Thu Aug 14 22:02:28 +0000 2025',
#    'text': 'Amazon Hits 100% Renewable Energy Goal 7 Years Ahead Of Schedule',
#    'lang': 'en',
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'quotes': 0,
#    'replies': 3,
#    'conversation_id': '1956114222628196862',
#    'retweets': 2,
#    'views': '11537',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'timestamps': [],
#     'urls': [],
#     'user_mentions': []},
#    'user_info': {'screen_name': 'FirstSquawk',
#     'name': 'First Squawk',
#     'created_at': 'Sun Jul 26 14:40:19 +0000 2015',
#     'description': 'Firstsquawk Is a Global Financial (News) Squawk Service Specialising In Financial Markets, Macro, Geopolitics,politics',
#     'rest_id': '3295423333',
#     'followers_count': 392265,
#     'favourites_count': 842,
#     'avatar': 'https://pbs.twimg.com/profile_images/1039778545738964992/6fl6RNN0_normal.jpg',
#     'verified': True,
#     'friends_count': 255,
#     'location': None},
#    'media': []},
#   {'type': 'tweet',
#    'tweet_id': '1956105209861575094',
#    'screen_name': 'FirstSquawk',
#    'bookmarks': 1,
#    'favorites': 8,
#    'created_at': 'Thu Aug 14 21:26:39 +0000 2025',
#    'text': 'HSBC Plans Major Global Expansion Of Office And Staff Surveillance – Documents',
#    'lang': 'en',
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'quotes': 0,
#    'replies': 5,
#    'conversation_id': '1956105209861575094',
#    'retweets': 1,
#    'views': '10698',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'timestamps': [],
#     'urls': [],
#     'user_mentions': []},
#    'user_info': {'screen_name': 'FirstSquawk',
#     'name': 'First Squawk',
#     'created_at': 'Sun Jul 26 14:40:19 +0000 2015',
#     'description': 'Firstsquawk Is a Global Financial (News) Squawk Service Specialising In Financial Markets, Macro, Geopolitics,politics',
#     'rest_id': '3295423333',
#     'followers_count': 392265,
#     'favourites_count': 842,
#     'avatar': 'https://pbs.twimg.com/profile_images/1039778545738964992/6fl6RNN0_normal.jpg',
#     'verified': True,
#     'friends_count': 255,
#     'location': None},
#    'media': []},
#   {'type': 'tweet',
#    'tweet_id': '1956105068576477661',
#    'screen_name': 'FirstSquawk',
#    'bookmarks': 1,
#    'favorites': 6,
#    'created_at': 'Thu Aug 14 21:26:05 +0000 2025',
#    'text': 'Palestinian Media: Israeli Shelling Hits Tent In Gaza’s Rimal Neighborhood, Killing Two And Injuring Others',
#    'lang': 'en',
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'quotes': 0,
#    'replies': 5,
#    'conversation_id': '1956105068576477661',
#    'retweets': 0,
#    'views': '9433',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'timestamps': [],
#     'urls': [],
#     'user_mentions': []},
#    'user_info': {'screen_name': 'FirstSquawk',
#     'name': 'First Squawk',
#     'created_at': 'Sun Jul 26 14:40:19 +0000 2015',
#     'description': 'Firstsquawk Is a Global Financial (News) Squawk Service Specialising In Financial Markets, Macro, Geopolitics,politics',
#     'rest_id': '3295423333',
#     'followers_count': 392265,
#     'favourites_count': 842,
#     'avatar': 'https://pbs.twimg.com/profile_images/1039778545738964992/6fl6RNN0_normal.jpg',
#     'verified': True,
#     'friends_count': 255,
#     'location': None},
#    'media': []}],
#  'next_cursor': 'DAADDAABCgABGyWeEKbXwNoKAAIbJXsyK9eR3QAIAAIAAAACCAADAAAAAAgABAAAAAAKAAUbJ75DmUAnEAoABhsnvkOZP9jwAAA',
#  'prev_cursor': 'DAADDAABCgABGyWeEKbXwNoKAAIbJXsyK9eR3QAIAAIAAAABCAADAAAAAAgABAAAAAAKAAUbJ75DmUAnEAoABhsnvkOZP9jwAAA'}

# %%
response.status_code
# Out:
# 200
